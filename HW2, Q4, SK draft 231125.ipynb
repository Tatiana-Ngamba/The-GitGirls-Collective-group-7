# %% [markdown]
# # Question 4: Describe the team approach to the project work [30 points]

# %% [markdown]
# _The 'Git Girls Collective 7' is a dynamic group of extremely capable and committed students, who worked together during Assignment 4 to produce really high quality output, of which we were all really proud. We have several advantages in terms of our diverse skillsets and backgrounds, and the willingness of every member to give significant time and effort to achieving an excellent group grade._

# %% [markdown]
# ## How we plan to distribute the project workload

# %% [markdown]
# One of the first tasks completed was to bring together and breakdown all the **Project requirements** from the CFG **Documentation**, gathering it in the 'Task' sheet of our Google Sheet.
#
# Later, once we had collectively decide to use **GitHub Projects** for **tagged task allocation**, we used the Tasks sheet to quickly populate the Projects task matrix, and will assign these tasks to GitHub profiles as we go.
#
# Another key part of our work distribution was paying attention to the **weightings in the Marking Criteria** chart (copied into our Google Sheet for easy reference). For example, we noted that Project Documentation is a very significant proportion of the grade: 30%! A way we visualised this was that, if we had been dividing tasks by percentage alone, this would be "2 people's" worth of total contribution! We immediately appreciated that this project was not just about code, but about evidence documentation, reporting, communication and visualisation skills, as well as demonstrating our ability to stay focussed on task and our collaborative-working skills.
#
# We noted that **all members need to contribute to code**, so we are making sure that everyone has contact with Python and/or SQL (according to strengths and preference where possible). We discussed that sometimes we may want to work together on code but also the need to be efficient relative to the Project dealine, and the other CFG Degree we each need to complete invidiaually whilst workin gon this. Pair-programming was floated as potentially a good tactic to afford all members hands-on contact with code, whilst pair-working can balance out individuals' strengths-weaknesses with particular languages.
#
# We will use the **Organisational Tools** listed in the next answer to enact and organise this distribution.
#
# **Virtual meetings** worked well for discussing ideas, updating on progress and distributing tasks during Assignment 4. These meetings are ideal for task distribution as we can quickly and efficiently discuss who would like to focus on what task. It also gives us the impetus to be **accountable**, reporting directly to one another face-face about our progress - this helps with ensuring that work is distributed fairly.

# %% [markdown]
# ## How we plan to work on our project

# %% [markdown]
# ### Organisational Tools
# **Slack**
# - Private channel Project-Group-7 is our primary **communication** medium. We utilise the main thread to share ideas and links, individual updates, ask questions and for general project conversation. We frequently post **summaries of our meetings**, and next meeting dates etc. We are not over-stringent on procedure, but try to keep things **organised by replying in-thread** where possible.  For example, if someone shares a link to a potential data-resource, other group members give reactions and feedback in-thread.
#
# - We improved our **file-sharing discipline** as we grew more comfortable with GitHub during Assignment 4, and now share code and files (like .csvs) exclusively through GitHub to maintain comment history, version control and distribution control.
#
# - Slack is a really important resouce for the group as it provides an **outlet for casual communications**, where we can **encourage eachother and celebrate** our progress. This has been key to how well our group has **bonded**. This outlet allows us to keep our other collaboration tools (like GitHub, and our shared Spreadsheets) more **professional** and clean.
#
# **GitHub**
# Learning how to use Git & GitHub during Assignment 4 was a steep learning curve for every group member, but pushing ourselves individually is paying off in our familiarity for the group Project. The group exclusively shares **code** for review, diff comparison and merge / update on GitHub. We all use meaningful **commit messages** to document changes to files.
#
# **GitHub Projects**
# The group decided to create a Projects tab, so that we could **integrate tasks** directly with pull requests, commits etc to clearly show progress related to code and file development. We are familiar with it from Assignment 4, and utilise the ability to **tag group members** for specfic tasks.
#
# **Google Sheet: Project Requirements**
# Pinned to our Slack workspace. This is a **communal sheet** for which we all have **full editing privileges**. We trialled this format in Assigment 4 and it worked well: sheets compartmentalise different segments of our Project work, and easily expand as we work on new categories. For example, the sheet began with 'Marking Criteria' (percentage weightings display helped us initially grasp project structure & most important aspects) and 'Tasks' tab which broke down every Project requirement (collected from the 3/4 CFG pdfs) into individual tasks, one task/requirement per cell. As we progress through the Project new Sheets will be added: for example we now have 'Dataset Links' (when we were exploring our resources) and now Data Questions, as we have reached that stage in our data handling. The sheet is great as it provides seamless collaboration and easy, lightweight, centralised viewing.
#
# **Project Activity Log Spreadsheet**
# Pinned to our Slack channel, we each have our own Activity Log as per project requirements. Because all members of our group commit a significant amount of time to our virtual meetings (often attended by all members), we have added a tab which documents the date of our **meetings**, time spent, topics discussed and outputs. This is to document and recognise this particular expression of how collaboratively our group works and our dedication to achieving a high quality end result.

# %% [markdown]
# ## What are your team’s strengths and weaknesses?

# %% [markdown]
# ### SWOT Analysis
# The group completed a verbal SWOT analysis during our first meeting (13th Nov). During Assignment 4 the group built up an excellent rapport and a supportive atmostphere where we could be honest about our different approaches and any challenges we came up against personally. This foundation really helped us all to be open about both our strengths and weaknesses right from the first session. One group member took notes of the discussion and put in a table in our Google Sheet.
# ![SWOT screenshot.JPG](attachment:0caa546c-9022-4221-91c7-435859d7f4c4.JPG)
#
# ### Key strengths
# The group identified a mixture of techncial and non-techncial skills:
# - **Technical**: experience with SQL, excel/visualistion and even some statistics/ML. We can produce really robust, well-thought out Python code.
# - **NTS**: we have some organisational queens in our group, those with superb documentation habits, strong writers and those with fantastic communication & diplomacy skills which are crucial for resolving differences in opinion and finding ways to keep moving forward.
# - **Diverse interests & experience**: all very driven individuals, our group brings a range of knowledge built from work and hobbies (e.g. fashion industry, employment, nutrition, pharaceuticals, cybersecurity). This gives us a wide experience base from which to draw when understanding data
# - **Mixed schedules**: the group discussed general work / free-time patterns so that we could manage expectations about when work would be completed generally by different members. We discussed how to use this to the group's advantage, taking a 'relay' approach with code where tasks sometimes may be allocated according to availability, in order that we can efficiently pass on code-progress to eachother, respecting our individual schedules.
#
# ### Weaknesses / Threats
# - Testament to the **supportive** environment of our group, some members shared how they work best (i.e. having tasks allocated) and highlighted how some communiation mediums were found to be more challenging than others. Additionally, the group identified any significant chunks of time (i.e. a few days) where any member will be **away**, so that individuals can **'front-load'** their contribution where required.

# %% [markdown]
# ## How our group managing our code

# %% [markdown]
# We share and manage our code via our **GitHub repository** _https://github.com/Tatiana-Ngamba/The-GitGirls-Collective-group-7/tree/main_
# Our thorough practice and learnings from Assignment 4 helped us set a structured but adaptable Repository structure:
# * **main** branch remains relatively clean, reserved for final Pull Request(s) with mature files
# * communal working branch 1: **Project_Code**
# * communal working branch 2: **Project_Documentation**
# * smaller branches will be utilised for significant but smaller work stages, like SQL-Database branch and Datasets branch
# * **individual members** will create their own named branch from whichever branch holds the files they are working on. Members will create pull requests from their own branch into the 'communal' destination branch when code/file updates are ready for review. This allows each member 'safe spaces' from which to alter and experiment with updating code.
#
# We're not afraid to **adapt** and if, for example, we found too many files in one branch, or realised a subset of files (i.e. raw dataset files) could be better categorised separately, we will create new branches or even use subfolders within branches.  We appreciate the difference between some files being mainly static, and just there for reference (i.e. datasets) whilst other files have dynamic content and will often be changing.
#
# The group has significantly improved **professionalism and discipline**, keeping control of file-sharing/versioning with GitHub whilst Slack shares links and general communications.

# %% [markdown]
# ## An expected timeline for our project

# %% [markdown]
# Timeline management was addressed in our first meeting (13th) where we divided rough progress into the 4-5 week 'chunks'.
# We also factored in the Marking Criteria weighting, acknowledging for instance that Project Documentation would need to have a significant time allocation.
#
# **Key timeline decisions (examples)**
# 1) All members appreciated that the **stage of choosing a high-quality dataset** was the most important, and would probably take a disproportionate amount of time. We appreciated that a dataset which would yield interesting quesions and analysis opportunities was crucial for the sucess of the rest of our progress. Therefore, this was the immediate practical task (sharing quality dataset ideas) and we made conscious decision not to rush this for the sake of keeping to an arbitrary timescale. However, we set a clear aim that we needed concrete ideas by the end of week 1 and that we wanted to be starting our actual data handling (cleaning, analysis) by the end of week 2.
#
# 3) Another example of our time management relates to **HW2**. We decided to alleviate the pressure of this interim dealine by getting ahead and having a draft finished by the end of Week 2, which aligns well with our aim of having solidified our base datasets and formulated our questions by this date also.

# %% [markdown]
# NEEDED -  Gant Chart/ Timeline, Screenshot & Explanation
